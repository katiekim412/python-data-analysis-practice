# %%
import os
import numpy as np
import pandas as pd

# %%
os.getcwd()
# Out:
# 'C:\\Users\\user\\Documents\\project\\code'

# %%
os.chdir(path = '../data')

# %%
os.listdir()
# Out:
# ['APT_Detail_Seoul_2024.csv',
#  'APT_Detail_Seoul_2024.xlsx',
#  'APT_List.pkl',
#  'APT_Prep.pkl',
#  'APT_Prep_New.pkl',
#  'APT_Price_Seoul(2020~2024).xlsx',
#  'APT_Price_Seoul_2020.csv',
#  'APT_Price_Seoul_2021.csv',
#  'APT_Price_Seoul_2022.csv',
#  'APT_Price_Seoul_2023.csv',
#  'APT_Price_Seoul_2024.csv',
#  'KBO_Hitter_Stats_2024.csv',
#  'KBO_Pitcher_Stats_2024.csv',
#  'MPRC_2024.csv',
#  'MPRC_2024.xlsx',
#  'MPRC_List.xlsx',
#  'MPRC_List_2.xlsx',
#  'NA_Sample.xlsx']

# %%
apt = pd.read_pickle('APT_Prep_New.pkl')

# %%
apt.shape
# Out:
# (220890, 12)

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm

# %%
fontList = fm.findSystemFonts(fontext = 'ttf')
fontList
# Out:
# ['C:\\Windows\\Fonts\\corbelb.ttf',
#  'C:\\Windows\\Fonts\\HancomEQN.ttf',
#  'C:\\Windows\\Fonts\\SitkaVF-Italic.ttf',
#  'C:\\Windows\\Fonts\\taile.ttf',
#  'C:\\Windows\\Fonts\\seguiemj.ttf',
#  'C:\\Windows\\Fonts\\verdanaz.ttf',
#  'C:\\Windows\\Fonts\\palab.ttf',
#  'C:\\Windows\\Fonts\\ntailu.ttf',
#  'C:\\Windows\\Fonts\\calibrili.ttf',
#  'C:\\Windows\\Fonts\\trebucbd.ttf',
#  'C:\\Windows\\Fonts\\phagspab.ttf',
#  'C:\\Windows\\Fonts\\tahoma.ttf',
#  'C:\\Windows\\Fonts\\mvboli.ttf',
#  'C:\\Windows\\Fonts\\segoeuib.ttf',
#  'C:\\Windows\\Fonts\\himalaya.ttf',
#  'C:\\Windows\\Fonts\\SimsunExtG.ttf',
#  'C:\\Windows\\Fonts\\consola.ttf',
#  'C:\\Windows\\Fonts\\cour.ttf',
#  'C:\\Windows\\Fonts\\seguisli.ttf',
#  'C:\\Windows\\Fonts\\HANBatangExtB.ttf',
#  'C:\\Windows\\Fonts\\seguisbi.ttf',
#  'C:\\Windows\\Fonts\\seguihis.ttf',
#  'C:\\Windows\\Fonts\\SitkaVF.ttf',
#  'C:\\Windows\\Fonts\\segoeuil.ttf',
#  'C:\\Windows\\Fonts\\corbeli.ttf',
# ...

# %%
fontPath = [font for font in fontList if 'Gowun' in font]
fontPath
# Out:
# ['C:\\Users\\user\\AppData\\Local\\Microsoft\\Windows\\Fonts\\GowunDodum-Regular.ttf',
#  'C:\\Users\\user\\AppData\\Local\\Microsoft\\Windows\\Fonts\\GowunBatang-Bold.ttf',
#  'C:\\Users\\user\\AppData\\Local\\Microsoft\\Windows\\Fonts\\GowunBatang-Regular.ttf']

# %%
for font in fontPath:
    print(fm.FontProperties(fname = font).get_name())
# Out:
# Gowun Dodum
# Gowun Batang
# Gowun Batang

# %%
plt.rc(group = 'font', family = 'Gowun Batang', size = 10)
plt.rc(group = 'figure', figsize = (8, 4), dpi = 100)
plt.rc(group = 'axes', unicode_minus = False)
plt.rc(group = 'legend', frameon = True, fc = '1', ec = '0')

# %%
apt['거래금액'].agg(func = ['min', 'max'])
# Out:
# min      0.62
# max    220.00
# Name: 거래금액, dtype: float64

# %%
sns.histplot(data = apt, x = '거래금액', binrange = (0, 220), binwidth = 2, fc = '1', ec = '0');

# %%
sns.histplot(data = apt, x = '거래금액', binrange = (0, 220), binwidth = 2, fc = 'pink', ec = 'red');

# %%
sns.histplot(data = apt, x = '거래금액', binrange = (0, 80), binwidth = 2, fc = '1', ec = '0');

# %%
sns.histplot(data = apt, x = '거래금액', binrange = (0, 80), binwidth = 2, hue = '재건축', ec = '0');

# %%
sns.histplot(data = apt, x = '거래금액', binrange = (0, 80), binwidth = 2, hue = '재건축', ec = '0', palette = 'Set1');

# %%
dir(plt.cm)
# Out:
# ['Accent',
#  'Accent_r',
#  'Blues',
#  'Blues_r',
#  'BrBG',
#  'BrBG_r',
#  'BuGn',
#  'BuGn_r',
#  'BuPu',
#  'BuPu_r',
#  'CMRmap',
#  'CMRmap_r',
#  'ColormapRegistry',
#  'Dark2',
#  'Dark2_r',
#  'GnBu',
#  'GnBu_r',
#  'Grays',
#  'Grays_r',
#  'Greens',
#  'Greens_r',
#  'Greys',
#  'Greys_r',
#  'Mapping',
#  'OrRd',
#  'OrRd_r',
#  'Oranges',
#  'Oranges_r',
#  'PRGn',
#  'PRGn_r',
#  'Paired',
#  'Paired_r',
#  'Pastel1',
#  'Pastel1_r',
#  'Pastel2',
#  'Pastel2_r',
#  'PiYG',
#  'PiYG_r',
#  'PuBu',
#  'PuBuGn',
#  'PuBuGn_r',
#  'PuBu_r',
#  'PuOr',
#  'PuOr_r',
#  'PuRd',
#  'PuRd_r',
#  'Purples',
#  'Purples_r',
#  'RdBu',
#  'RdBu_r',
#  'RdGy',
#  'RdGy_r',
#  'RdPu',
#  'RdPu_r',
#  'RdYlBu',
#  'RdYlBu_r',
#  'RdYlGn',
#  'RdYlGn_r',
#  'Reds',
#  'Reds_r',
#  'ScalarMappable',
#  'Set1',
#  'Set1_r',
#  'Set2',
#  'Set2_r',
#  'Set3',
#  'Set3_r',
#  'Spectral',
#  'Spectral_r',
#  'Wistia',
#  'Wistia_r',
#  'YlGn',
#  'YlGnBu',
#  'YlGnBu_r',
#  'YlGn_r',
# ...

# %%
plt.cm.Greys

# %%
plt.cm.Greys_r

# %%
plt.cm.YlOrRd

# %%
plt.cm.Spectral

# %%
plt.cm.RdYlGn

# %%
plt.cm.Set1

# %%
plt.cm.tab10

# %%
plt.cm.twilight

# %%
plt.cm.winter

# %%
sns.color_palette()
# Out:
# [(0.12156862745098039, 0.4666666666666667, 0.7058823529411765),
#  (1.0, 0.4980392156862745, 0.054901960784313725),
#  (0.17254901960784313, 0.6274509803921569, 0.17254901960784313),
#  (0.8392156862745098, 0.15294117647058825, 0.1568627450980392),
#  (0.5803921568627451, 0.403921568627451, 0.7411764705882353),
#  (0.5490196078431373, 0.33725490196078434, 0.29411764705882354),
#  (0.8901960784313725, 0.4666666666666667, 0.7607843137254902),
#  (0.4980392156862745, 0.4980392156862745, 0.4980392156862745),
#  (0.7372549019607844, 0.7411764705882353, 0.13333333333333333),
#  (0.09019607843137255, 0.7450980392156863, 0.8117647058823529)]

# %%
sns.set_palette(palette = 'Set1')

# %%
sns.color_palette()
# Out:
# [(0.8941176470588236, 0.10196078431372549, 0.10980392156862745),
#  (0.21568627450980393, 0.49411764705882355, 0.7215686274509804),
#  (0.30196078431372547, 0.6862745098039216, 0.2901960784313726),
#  (0.596078431372549, 0.3058823529411765, 0.6392156862745098),
#  (1.0, 0.4980392156862745, 0.0),
#  (1.0, 1.0, 0.2),
#  (0.6509803921568628, 0.33725490196078434, 0.1568627450980392),
#  (0.9686274509803922, 0.5058823529411764, 0.7490196078431373),
#  (0.6, 0.6, 0.6)]

# %%
sns.histplot(data = apt, x = '거래금액', binrange = (0, 80), binwidth = 2, hue = '재건축', ec = '0');

# %%
apt1 = apt.sort_values(by = '재건축', ascending = False)
apt1.head()
# Out:
#         거래금액  시군구  법정동  계약년도 계약월    전용면적   층         평당금액  경과년수 재건축   세대수  \
# 140335  9.30  관악구  신림동  2023   4  119.49  12  2568.415767    30  충족  1634
# 98022   5.20  도봉구   창동  2021   4   41.30   6  4154.963680    31  충족   808
# 98020   4.75  도봉구   창동  2021   4   36.16   7  4334.900442    32  충족  1980
# 174035  6.40  강북구  수유동  2024   7   84.92   4  2487.046632    31  충족  1454
# 98018   5.60  도봉구   창동  2021   4   36.16  12  5110.619469    31  충족   750
#
#         주차대수
# 140335  2124
# 98022    618
# 98020    537
# 174035  1130
# 98018    313

# %%
sns.histplot(data = apt1, x = '거래금액', binrange = (0, 80), binwidth = 2, hue = '재건축', ec = '0');

# %%
sns.histplot(data = apt, x = '거래금액', binrange = (0, 80), binwidth = 2, hue = '재건축', ec = '0', 
             hue_order = ['충족', '부족']);

# %%
mypal = sns.color_palette(palette = ['silver', 'red', 'darkred'], as_cmap = True)

# %%
sns.histplot(data = apt, x = '거래금액', binrange = (0, 80), binwidth = 2, hue = '재건축', ec = '0', 
             palette = mypal);
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_11432\3238538271.py:1: UserWarning: The palette list has more values (3) than needed (2), which may not be intended.
#   sns.histplot(data = apt, x = '거래금액', binrange = (0, 80), binwidth = 2, hue = '재건축', ec = '0',

# %%
sns.histplot(data = apt, x = '거래금액', binrange = (0, 80), binwidth = 2, hue = '재건축', ec = '0', 
             palette = {'부족': 'silver', '충족': 'red'})
plt.title(label = '아파트 거래금액의 분포', fontweight = 'bold', size = 20, color = 'red', y = 0.8)
plt.xlabel(xlabel = '거래금액(억)', fontdict = {'family': 'Malgun Gothic', 'color': 'blue'}, loc = 'right')
plt.ylabel(ylabel = '거래건수(건)', loc = 'top');

# %%
sns.histplot(data = apt, x = '거래금액', binrange = (0, 80), binwidth = 2, 
             fc = '1', ec = '0.8', kde = True, color = 'red')
plt.xlim(-4, 84);

# %%
sns.histplot(data = apt, x = '거래금액', binrange = (0, 80), binwidth = 2, 
             fc = '1', ec = '0.8', stat = 'density')
sns.kdeplot(data = apt, x = '거래금액', color = 'red', lw = 1, ls = '--')
plt.xlim(-4, 84);

# %%
cond = apt['시군구'].str.contains(pat = '강[남동북]')
sub = apt.loc[cond, :]

# %%
pd.pivot_table(data = sub, index = '시군구', values = '거래금액', 
               aggfunc = ['count', 'mean', 'std'])
# Out:
#      count       mean        std
#       거래금액       거래금액       거래금액
# 시군구
# 강남구  12291  20.857690  12.250572
# 강동구  11958   9.412720   4.219959
# 강북구   4875   5.881168   2.092242

# %%
sns.histplot(data = sub, x = '거래금액', binrange = (0, 80), binwidth = 2, 
             hue = '시군구', ec = '0');

# %%
sns.kdeplot(data = sub, x = '거래금액', hue = '시군구', fill = True, palette = mypal)
plt.xlim(-4, 84);

# %%
out_prop = {
    'marker': '*', 
    'markersize': 3, 
    'markerfacecolor': 'pink', 
    'markeredgecolor': 'red', 
    'markeredgewidth': 0.5
}

# %%
sns.boxplot(data = apt, y = '거래금액', color = '0.8', linewidth = 0.5, flierprops = out_prop);

# %%
grp = apt.groupby(by = '시군구')['거래금액'].median().sort_values()
grp.head()
# Out:
# 시군구
# 도봉구    4.9
# 금천구    5.4
# 노원구    5.5
# 중랑구    5.7
# 강북구    6.0
# Name: 거래금액, dtype: float64

# %%
sns.boxplot(data = apt, x = '시군구', y = '거래금액', color = '0.8', linewidth = 0.5, flierprops = out_prop, 
            order = grp.index)
plt.axhline(y = apt['거래금액'].median(), color = 'red', lw = 1, ls = '--')
plt.axvline(x = 10.5, color = 'black', lw = 1, ls = '-')
plt.axvline(x = 16.5, color = 'black', lw = 1, ls = '-')
plt.xticks(rotation = 90, fontsize = 8);

# %% [raw]
# sns.boxplot(data = apt1, x = '시군구', y = '거래금액', color = '0.8', linewidth = 0.5, flierprops = out_prop)
# plt.xticks(rotation = 90, fontsize = 8);

# %%
sns.boxplot(data = sub, x = '시군구', y = '거래금액', color = '0.8', flierprops = out_prop);

# %%
grp = apt['시군구'].value_counts()
grp.head()
# Out:
# 시군구
# 노원구    19204
# 송파구    14186
# 강서구    13610
# 강남구    12291
# 성북구    11995
# Name: count, dtype: int64

# %%
plt.figure(figsize = (12, 4))
sns.countplot(data = apt, x = '시군구', facecolor = '0.8', order = grp.index)
plt.xticks(rotation = 90, fontsize = 8)
plt.xlim(-1, 25)
plt.ylim(0, 22500)
for i, v in enumerate(grp):
    plt.text(x = i, y = v + 200, s = f'{v:,}', ha = 'center', va = 'bottom', fontsize = 8);

# %%
mypal = ['red'] + ['silver'] * 24

# %%
plt.figure(figsize = (8, 6))
sns.countplot(data = apt, y = '시군구', hue = '시군구', order = grp.index, palette = mypal, hue_order = grp.index)
plt.xlim(0, 22500)
plt.ylim(25, -1)
for i, v in enumerate(grp):
    plt.text(x = v - 200, y = i, s = f'{v:,}', ha = 'right', va = 'center', fontsize = 8);

# %%
grp = apt.groupby(by = '시군구')['거래금액'].mean().sort_values()
grp.head()
# Out:
# 시군구
# 도봉구    5.128583
# 금천구    5.631871
# 중랑구    5.766280
# 노원구    5.877245
# 강북구    5.881168
# Name: 거래금액, dtype: float64

# %%
mypal = ['silver'] * 25
mypal[13] = 'red'

# %%
plt.figure(figsize = (12, 4))
sns.barplot(data = apt, x = '시군구', y = '거래금액', hue = '시군구', hue_order = grp.index, 
            errorbar = None, order = grp.index, palette = mypal)
plt.xticks(rotation = 90, fontsize = 8)
plt.xlim(-1, 25)
plt.ylim(0, 22.5)
for i, v in enumerate(grp):
    plt.text(x = i, y = v + 0.2, s = f'{v:.1f}억', ha = 'center', va = 'bottom', fontsize = 7);

# %%
grp = apt.groupby(by = '시군구')['평당금액'].mean().sort_values()
grp.head()
# Out:
# 시군구
# 도봉구    2468.478297
# 금천구    2771.375619
# 강북구    2799.757455
# 중랑구    2865.229674
# 구로구    2982.669876
# Name: 평당금액, dtype: float64

# %%
mypal = ['silver'] * 25
mypal[22] = 'red'

# %%
plt.figure(figsize = (12, 4))
sns.barplot(data = apt, x = '시군구', y = '평당금액', hue = '시군구', hue_order = grp.index, 
            errorbar = None, order = grp.index, palette = mypal)
plt.xticks(rotation = 90, fontsize = 8)
plt.xlim(-1, 25)
plt.ylim(0, 9000)
for i, v in enumerate(grp):
    plt.text(x = i, y = v + 100, s = f'{v:,.0f}', ha = 'center', va = 'bottom', fontsize = 7);

# %%
apt.dtypes
# Out:
# 거래금액    float64
# 시군구      object
# 법정동      object
# 계약년도     object
# 계약월      object
# 전용면적    float64
# 층         int64
# 평당금액    float64
# 경과년수      int64
# 재건축      object
# 세대수       int64
# 주차대수      int64
# dtype: object

# %%
apt['계약월'] = apt['계약월'].astype(int)

# %%
sns.lineplot(data = apt, x = '계약월', y = '거래금액', errorbar = None, marker = 'o')
plt.xticks(ticks = range(1, 13), labels = [f'{i}월' for i in range(1, 13)])
plt.ylim(8, 12);

# %%
sns.lineplot(data = apt, x = '계약월', y = '거래금액', hue = '계약년도', errorbar = None, marker = 'o')
plt.xticks(ticks = range(1, 13), labels = [f'{i}월' for i in range(1, 13)])
plt.ylim(6, 14);

# %%
sns.lineplot(data = apt, x = '계약월', y = '거래금액', hue = '계약년도', errorbar = None, 
             style = '계약년도', markers = True, dashes = True)
plt.xticks(ticks = range(1, 13), labels = [f'{i}월' for i in range(1, 13)])
plt.ylim(6, 14)
plt.legend(loc = 'center right');

# %%
sns.lineplot(data = apt, x = '계약월', y = '거래금액', hue = '계약년도', errorbar = None, 
             style = '계약년도', markers = True, dashes = True)
plt.xticks(ticks = range(1, 13), labels = [f'{i}월' for i in range(1, 13)])
plt.ylim(6, 14)
plt.legend(loc = 'center left', bbox_to_anchor = (1, 0.5));

# %%
sns.lineplot(data = apt, x = '계약월', y = '거래금액', hue = '계약년도', errorbar = None, 
             style = '계약년도', markers = True, dashes = True)
plt.xticks(ticks = range(1, 13), labels = [f'{i}월' for i in range(1, 13)])
plt.ylim(6, 14)
plt.legend(loc = 'lower center', bbox_to_anchor = (0.5, 1), ncol = 5)
plt.title(label = '월별 거래금액의 평균 변화량', y = 1.1);

# %%
sns.lineplot(data = sub, x = '계약월', y = '거래금액', hue = '시군구', errorbar = None, 
             style = '시군구', markers = True, dashes = True)
plt.xticks(ticks = range(1, 13), labels = [f'{i}월' for i in range(1, 13)])
# plt.ylim(6, 14)
plt.legend(loc = 'lower center', bbox_to_anchor = (0.5, 1), ncol = 5)
plt.title(label = '월별 거래금액의 평균 변화량', y = 1.1);

# %%
sns.scatterplot(data = apt, x = '전용면적', y = '거래금액', fc = '0.9', ec = '0.5', 
                s = 20, alpha = 0.5);

# %%
apt = apt.sort_values(by = '세대수')

# %%
sns.scatterplot(data = apt, x = '전용면적', y = '거래금액', hue = '세대수', ec = '0.5', 
                palette = 'Greys', s = 20, alpha = 0.5);

# %%
cond = apt['시군구'].eq('강남구')
gng = apt.loc[cond, :]

# %%
sns.scatterplot(data = gng, x = '전용면적', y = '거래금액', hue = '세대수', ec = '0.5', 
                palette = 'Greys', s = 20, alpha = 0.5);

# %%
cond = apt['시군구'].eq('송파구')
spg = apt.loc[cond, :]

# %%
sns.scatterplot(data = spg, x = '전용면적', y = '거래금액', hue = '세대수', ec = '0.5', 
                palette = 'Greys', s = 20, alpha = 0.5);

# %%
point_prop = dict(fc = '0.9', ec = '0.8', s = 20, alpha = 0.5)
line_prop = dict(color = 'red', lw = 1, ls = '-')

# %%
sns.regplot(data = gng, x = '전용면적', y = '거래금액', ci = None, 
            scatter_kws = point_prop, line_kws = line_prop);

# %%
sns.regplot(data = gng, x = '세대수', y = '거래금액', ci = None, 
            scatter_kws = point_prop, line_kws = line_prop);

# %%
sns.regplot(data = gng, x = '주차대수', y = '거래금액', ci = None, 
            scatter_kws = point_prop, line_kws = line_prop);

# %%
sns.regplot(data = gng, x = '층', y = '거래금액', ci = None, 
            scatter_kws = point_prop, line_kws = line_prop);

# %%
# 상관계수 행렬
gng.corr(numeric_only = True)
# Out:
#           거래금액       계약월      전용면적         층      평당금액      경과년수       세대수  \
# 거래금액  1.000000  0.054874  0.785127  0.236852  0.554092  0.185961  0.201391
# 계약월   0.054874  1.000000  0.003274 -0.004510  0.086730 -0.000332 -0.034389
# 전용면적  0.785127  0.003274  1.000000  0.191205  0.012713  0.121857 -0.018238
# 층     0.236852 -0.004510  0.191205  1.000000  0.117339 -0.183739  0.054178
# 평당금액  0.554092  0.086730  0.012713  0.117339  1.000000  0.146279  0.403711
# 경과년수  0.185961 -0.000332  0.121857 -0.183739  0.146279  1.000000  0.172050
# 세대수   0.201391 -0.034389 -0.018238  0.054178  0.403711  0.172050  1.000000
# 주차대수  0.330900 -0.026298  0.137838  0.276546  0.409259 -0.120478  0.836277
#
#           주차대수
# 거래금액  0.330900
# 계약월  -0.026298
# 전용면적  0.137838
# 층     0.276546
# 평당금액  0.409259
# 경과년수 -0.120478
# 세대수   0.836277
# 주차대수  1.000000

# %%
sns.heatmap(data = gng.corr(numeric_only = True), 
            annot = True, 
            fmt = '.2f', 
            cmap = 'RdYlBu');
